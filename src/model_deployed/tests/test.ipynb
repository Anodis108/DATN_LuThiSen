# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

#Custom function to show open cv image on notebook.
def display_img(cvImg):
    cvImg = cv2.cvtColor(cvImg, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(10,8))
    plt.imshow(cvImg)
    plt.axis('off')
    plt.show()

# %%
#Loading image using cv2
baseImg = cv2.imread(r'/mnt/d/project/DATN/DATN_LuThiSen/resource/data/base_card.jpg')

#Declare image size, width height and chanel
baseH, baseW, baseC = baseImg.shape

display_img(baseImg)

# %% [markdown]
# # Detect cccd

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load mô hình YOLOv8 đã huấn luyện
model = YOLO('/mnt/d/project/DATN/DATN_LuThiSen/resource/weights/last_detect_card_1004202510042025.pt')

# Đọc ảnh
image_path = '/mnt/d/project/DATN/DATN_LuThiSen/resource/data/demo_data_card/LuThiSen1.jpg'
image = cv2.imread(image_path)
image_with_box = image.copy()  # Copy để vẽ bbox
img2 = None

# Detect object
results = model(image)
print(results[0].boxes)

for result in results:
    for box in result.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Lấy tọa độ bounding box
        conf = float(box.conf[0])  # Độ tin cậy (confidence)

        # Crop ảnh CCCD
        img2 = image[y1:y2, x1:x2]
        bbox = box.xyxy[0].cpu().numpy()
        print(f"Crop shape: {img2.shape}, BBox: {bbox}, Conf: {conf:.2%}")

        # Vẽ bounding box với độ dày 4px, màu xanh lá
        cv2.rectangle(image_with_box, (x1, y1), (x2, y2), (0, 255, 0), thickness=4)

        # Ghi độ tin cậy lên ảnh
        label = f"Conf: {conf * 100:.1f}%"
        cv2.putText(image_with_box, label, (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)  # Đỏ, đậm

        # Lưu ảnh đã crop
        cv2.imwrite("card_crop.jpg", img2)

        # Hiển thị ảnh crop
        plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
        plt.title("Cropped CCCD")
        plt.axis("off")
        plt.show()

# Hiển thị ảnh đã vẽ bbox
plt.imshow(cv2.cvtColor(image_with_box, cv2.COLOR_BGR2RGB))
plt.title("Detected Bounding Box")
plt.axis("off")
plt.show()

# Lưu ảnh có bounding box
cv2.imwrite("output_detect.jpg", image_with_box)
# Out:
# 0: 640x480 1 card, 68.3ms
# Speed: 5.9ms preprocess, 68.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.9007], device='cuda:0')
# data: tensor([[1.5060e+02, 1.0180e+03, 1.4849e+03, 1.9124e+03, 9.0067e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (2560, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 817.7399, 1465.2083, 1334.2747,  894.4327]], device='cuda:0')
# xywhn: tensor([[0.4259, 0.5723, 0.6949, 0.3494]], device='cuda:0')
# xyxy: tensor([[ 150.6025, 1017.9919, 1484.8772, 1912.4246]], device='cuda:0')
# xyxyn: tensor([[0.0784, 0.3977, 0.7734, 0.7470]], device='cuda:0')
# Crop shape: (895, 1334, 3), BBox: [      150.6        1018      1484.9      1912.4], Conf: 90.07%
# True

# %% [markdown]
# # Preprocess image

# %%
#Init orb, keypoints detection on base Image
orb = cv2.ORB_create(3000)

kp, des = orb.detectAndCompute(baseImg, None)
imgKp = cv2.drawKeypoints(baseImg,kp, None)

display_img(imgKp)

# %%
PER_MATCH = 0.25

#Detect keypoint on img2
kp1, des1 = orb.detectAndCompute(img2, None)

#Init BF Matcher, find the matches points of two images
bf = cv2.BFMatcher(cv2.NORM_HAMMING)
matches = list(bf.match(des1, des))

#Select top 30% best matcher 
matches.sort(key=lambda x: x.distance)
best_matches = matches[:int(len(matches)*PER_MATCH)]

#Show match img  
imgMatch = cv2.drawMatches(img2, kp1, baseImg, kp, best_matches,None, flags=2)
display_img(imgMatch)

# %%
#Init source points and destination points for findHomography function.
srcPoints = np.float32([kp1[m.queryIdx].pt for m in best_matches]).reshape(-1,1,2)
dstPoints = np.float32([kp[m.trainIdx].pt for m in best_matches]).reshape(-1,1,2)


#Find Homography of two images
matrix_relationship, _ = cv2.findHomography(srcPoints, dstPoints,cv2.RANSAC, 5.0)

#Transform the image to have the same structure as the base image
img_final = cv2.warpPerspective(img2, matrix_relationship, (baseW, baseH))

display_img(img_final)

# %% [markdown]
# # Text detect

# %%
# prepare data

# Thư mục chứa ảnh đầu vào
input_folder = "/home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/demo_data_card"

# Thư mục chứa ảnh đầu ra (tạo nếu chưa có)
output_folder = "/home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card"
os.makedirs(output_folder, exist_ok=True)

# Load mô hình YOLO đã huấn luyện
model = YOLO("/home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/weights/last_detect_card_1004202510042025.pt")

# Lấy danh sách file ảnh trong thư mục input
image_files = [f for f in os.listdir(input_folder) if f.endswith((".jpg", ".png", ".jpeg"))]
print(image_files)
# Đếm số lượng ảnh đã lưu
count = 1

for image_name in image_files:
    image_path = os.path.join(input_folder, image_name)
    image = cv2.imread(image_path)
    if image is None:
        print(f"Lỗi khi đọc ảnh: {image_name}")
        continue

    # Detect CCCD
    results = model(image)

    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Lấy tọa độ bounding box
            bbox = box.xyxy[0].cpu().numpy()
            print(bbox)
            # Cắt ảnh CCCD từ ảnh gốc
            cropped_img = image[y1:y2, x1:x2]

            # Lưu ảnh đã cắt vào thư mục output
            output_path = os.path.join(output_folder, f"cccd_{count}.jpg")
            cv2.imwrite(output_path, cropped_img)
            print(f"Lưu ảnh: {output_path}")
            count += 1  # Tăng số thứ tự ảnh
# Out:
# ['NguyenMinhHieu2.jpg', 'LeThiPhuong1.jpg', 'NguyenTrangNhung2.jpg', 'NguyenTrangNhung3.jpg', 'NguyenTrongTuan2.jpg', 'LuThiSen1.jpg', 'TranMinhTuan1.jpg', 'DuongVanDung1.jpg', 'TranMinhTuan2.jpg', 'NguyenThiHuyenTrang2.jpg', 'NguyenQuyetThang2.jpg', 'NguyenThiHuyenTrang3.jpg', 'NguyenTrongTuan1.jpg', 'NguyenTrongTuan4.jpg', 'NguyenMinhHieu1.jpg', 'NguyenThiHuyenTrang4.jpg', 'LuongBaHoang2.jpg', 'LuThiSen4.jpg', 'TrinhGiaLoc3.jpg', 'NguyenThiHuyenTrang1.jpg', 'NguyenMinhHieu3.jpg', 'NguyenTrongTuan3.jpg', 'NguyenTrangNhung1.jpg', 'TrinhGiaLoc1.jpg', 'NguyenQuyetThang1.jpg', 'NguyenQuyetThang3.jpg', 'LeThiPhuong4.jpg', 'PhamQuyQuoc3.jpg', 'DuongVanDung3.jpg', 'LuThihSen3.jpg', 'TranMinhTuan4.jpg', 'NguyenDinhLinh1.jpg', 'NguyenQuyetThang4.jpg', 'DuongVanDung2.jpg', 'LeThiPhuong3.jpg', 'LuThiSen2.jpg', 'LuongBaHoang1.jpg', 'PhamQuyQuoc4.jpg', 'TrinhGiaLoc2.jpg', 'NguyenDinhLinh3.jpg', 'PhamQuyQuoc1.jpg', 'LeThiPhuong2.jpg', 'LuongBaHoang3.jpg', 'PhamQuyQuoc2.jpg', 'NguyenDinhLinh2.jpg', 'NguyenTrangNhung4.jpg', 'DuongVanDung4.jpg', 'TranMinhTuan3.jpg']
#
# 0: 480x640 1 card, 40.4ms
# Speed: 1.6ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# [    0.62155      6.7106         944      660.34]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_1.jpg
#
# 0: 640x480 1 card, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# [     166.58      617.93      1390.9      1392.7]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_2.jpg
#
# 0: 640x480 1 card, 8.9ms
# Speed: 2.3ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# [     210.41      500.06        1274      1771.8]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_3.jpg
#
# 0: 640x480 1 card, 9.0ms
# Speed: 2.2ms preprocess, 9.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# [     312.48       369.5      1242.2        1765]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_4.jpg
#
# 0: 640x320 1 card, 49.4ms
# Speed: 1.6ms preprocess, 49.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 320)
# [     9.9708      670.21      879.54      1242.5]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_5.jpg
#
# 0: 640x480 1 card, 9.4ms
# Speed: 2.2ms preprocess, 9.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# [     150.61        1018      1484.9      1912.4]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_6.jpg
#
# 0: 640x480 1 card, 8.9ms
# Speed: 2.1ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# [      1.711      475.08      1491.9        1631]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_7.jpg
#
# 0: 640x640 1 card, 11.5ms
# Speed: 2.6ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# [          0      588.42      2541.7      2259.7]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_8.jpg
#
# 0: 640x480 1 card, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# [     216.62      821.02      1337.9      1538.4]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_9.jpg
#
# 0: 480x640 3 cards, 9.7ms
# Speed: 2.0ms preprocess, 9.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# [     526.86      517.45      1792.2        1401]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_10.jpg
# [      3.417      1.3159      1132.7      443.26]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_11.jpg
# [     411.55     0.38467      2042.4      456.02]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_12.jpg
#
# 0: 640x480 1 card, 9.4ms
# Speed: 2.0ms preprocess, 9.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# [     7.5363      264.81        1536      1830.8]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_13.jpg
#
# 0: 480x640 2 cards, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# [     440.21      428.37      1786.5      1519.4]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_14.jpg
# [     163.53           0      2010.3       427.6]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_15.jpg
#
# 0: 640x320 1 card, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 320)
# [     95.411      378.12      833.59      1497.2]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_16.jpg
#
# 0: 640x320 1 card, 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 320)
# [     11.698      539.12      892.53      1432.2]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_17.jpg
#
# 0: 640x320 1 card, 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 320)
# [          0       302.6      924.01        1801]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_18.jpg
#
# 0: 480x640 3 cards, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# [     485.11      564.98      1821.8      1418.8]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_19.jpg
# [     1297.4      1.9198      2039.8      510.58]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_20.jpg
# [      5.743           0      1951.1      519.06]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_21.jpg
#
# 0: 640x384 1 card, 45.3ms
# Speed: 1.6ms preprocess, 45.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# [     196.81      669.86       994.8      1370.5]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_22.jpg
#
# 0: 640x480 1 card, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# [     105.97      665.99      1716.3      2168.4]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_23.jpg
#
# 0: 640x480 1 card, 8.9ms
# Speed: 2.3ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# [    0.36562      309.25        1431      1776.8]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_24.jpg
#
# 0: 480x640 2 cards, 9.7ms
# Speed: 1.9ms preprocess, 9.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# [     503.81      508.91      1865.2      1524.8]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_25.jpg
# [     92.119           0      2011.6      499.17]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_26.jpg
#
# 0: 576x640 1 card, 44.6ms
# Speed: 1.8ms preprocess, 44.6ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 640)
# [        1.3      35.716         944      795.41]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_27.jpg
#
# 0: 640x320 1 card, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 320)
# [     31.559      701.83      891.82      1275.7]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_28.jpg
#
# 0: 640x480 1 card, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# [          0      30.616      1478.1      1872.9]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_29.jpg
#
# 0: 640x480 1 card, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# [     102.89      469.77        1322      1259.9]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_30.jpg
#
# 0: 640x480 1 card, 8.9ms
# Speed: 2.2ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# [     98.839       679.5      1455.8      1570.8]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_31.jpg
#
# 0: 640x480 1 card, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# [     230.37      663.38      1317.6      1334.6]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_32.jpg
#
# 0: 640x480 1 card, 8.9ms
# Speed: 2.1ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# [     152.82      663.87      1383.8      1516.7]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_33.jpg
#
# 0: 640x480 1 card, 9.0ms
# Speed: 2.7ms preprocess, 9.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# [     138.98      628.09      1409.7      1784.1]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_34.jpg
#
# 0: 640x640 1 card, 11.9ms
# Speed: 2.4ms preprocess, 11.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# [     13.375           0      2549.5      2545.3]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_35.jpg
#
# 0: 640x480 1 card, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# [     248.87      846.99      1607.4      1715.1]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_36.jpg
#
# 0: 640x480 1 card, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# [     130.43      747.33      1371.9      1544.3]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_37.jpg
#
# 0: 480x640 1 card, 9.7ms
# Speed: 2.3ms preprocess, 9.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# [          0      50.037        2495        1824]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_38.jpg
#
# 0: 640x480 1 card, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# [     24.295      472.75      1526.8      1461.1]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_39.jpg
#
# 0: 640x640 1 card, 11.4ms
# Speed: 2.4ms preprocess, 11.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# [     3.1816         107      2539.7      2550.9]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_40.jpg
#
# 0: 640x480 1 card, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# [      113.4      578.04      1409.3      1749.9]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_41.jpg
#
# 0: 640x480 1 card, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# [     165.98      741.84      1435.1      2141.7]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_42.jpg
#
# 0: 640x384 2 cards, 7.5ms
# Speed: 1.7ms preprocess, 7.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# [     220.11      851.13      885.82      1307.8]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_43.jpg
# [     13.166           0      1073.8      110.74]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_44.jpg
#
# 0: 640x480 1 card, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# [     169.38      742.24      1320.2      1522.3]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_45.jpg
#
# 0: 640x480 1 card, 8.9ms
# Speed: 2.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# [     47.572      207.02        1536      1944.5]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_46.jpg
#
# 0: 640x480 1 card, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# [     66.987      596.89      1907.3      1851.9]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_47.jpg
#
# 0: 640x480 1 card, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# [      98.58      729.39      1351.7      1574.4]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_48.jpg
#
# 0: 640x480 1 card, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# [     232.26      599.95      1305.6      1719.6]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_49.jpg
#
# 0: 640x384 1 card, 7.6ms
# Speed: 1.8ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# [     227.97      652.94      777.79      1361.1]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_50.jpg
#
# 0: 640x480 1 card, 9.4ms
# Speed: 1.9ms preprocess, 9.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# [     140.77      520.16      1457.4        1699]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_51.jpg
#
# 0: 640x480 1 card, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# [      289.2      448.41      1877.3      2111.3]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_52.jpg
#
# 0: 640x480 1 card, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# [     76.365      561.13      1334.2      1341.8]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_53.jpg
#
# 0: 640x640 1 card, 11.6ms
# Speed: 2.8ms preprocess, 11.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# [     386.79      59.611      2069.2        2560]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_54.jpg
#
# 0: 640x480 1 card, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# [     77.788      507.63      1522.5      1831.1]
# Lưu ảnh: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card/cccd_55.jpg

# %%
import cv2
import os
import glob
def transform(img):
    #Init orb, keypoints detection on base Image
    orb = cv2.ORB_create(1000)
    kp, des = orb.detectAndCompute(baseImg, None)
    PER_MATCH = 0.25

    #Detect keypoint on img
    kp1, des1 = orb.detectAndCompute(img, None)

    #Init BF Matcher, find the matches points of two images
    bf = cv2.BFMatcher(cv2.NORM_HAMMING)
    matches = list(bf.match(des1, des))

    #Select top 30% best matcher 
    matches.sort(key=lambda x: x.distance)
    best_matches = matches[:int(len(matches)*PER_MATCH)]
    
    #Init source points and destination points for findHomography function.
    srcPoints = np.float32([kp1[m.queryIdx].pt for m in best_matches]).reshape(-1,1,2)
    dstPoints = np.float32([kp[m.trainIdx].pt for m in best_matches]).reshape(-1,1,2)


    #Find Homography of two images
    matrix_relationship, _ = cv2.findHomography(srcPoints, dstPoints,cv2.RANSAC, 5.0)

    #Transform the image to have the same structure as the base image
    img_final = cv2.warpPerspective(img, matrix_relationship, (baseW, baseH))

    return img_final

    
# Thư mục nguồn và đích
source_folder = "/home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card"  # Thay bằng đường dẫn thư mục chứa ảnh gốc
destination_folder = "/home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated"  # Thay bằng đường dẫn thư mục đích

# Tạo thư mục đích nếu chưa có
os.makedirs(destination_folder, exist_ok=True)

image_paths = sorted(glob.glob(os.path.join(source_folder, "*.*")), key=os.path.basename)

# Duyệt qua từng ảnh
for idx, image_path in enumerate(image_paths, start=1):
    # Đọc ảnh
    img = cv2.imread(image_path)
    
    # Tạo tên file mới theo thứ tự
    new_filename = os.path.join(destination_folder, f"{idx:04d}.png")  # 0001.png, 0002.png,...
    
    # Ghi ảnh vào thư mục đích
    cv2.imwrite(new_filename, transform(img))
    print(f"Đã lưu: {new_filename}")

print("Hoàn thành xử lý ảnh!")
# Out:
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0001.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0002.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0003.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0004.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0005.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0006.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0007.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0008.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0009.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0010.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0011.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0012.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0013.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0014.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0015.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0016.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0017.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0018.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0019.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0020.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0021.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0022.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0023.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0024.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0025.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0026.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0027.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0028.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0029.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0030.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0031.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0032.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0033.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0034.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0035.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0036.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0037.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0038.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0039.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0040.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0041.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0042.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0043.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0044.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0045.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0046.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0047.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0048.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0049.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0050.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0051.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0052.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0053.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0054.png
# Đã lưu: /home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_card_rotated/0055.png
# Hoàn thành xử lý ảnh!

# %%
import cv2
import torch
from ultralytics import YOLO
model = YOLO("/home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/weights/detect_text_best.pt")  # Có thể thay bằng yolov8n.pt, yolov8m.pt, ...

# Đọc ảnh
image_path = "/home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/output_cccd_rotated/0003.png"
image = cv2.imread(image_path)

# Chạy model YOLO detect vật thể
results = model(image)

# Danh sách lưu thông tin vật thể
image_text_list = []

# Duyệt qua từng vật thể được phát hiện
for result in results:
    for box in result.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Lấy tọa độ (xmin, ymin, xmax, ymax)
        bbox = box.xyxy[0].cpu().numpy()
        
        cropped_img_image = image[y1:y2, x1:x2] 
        
        conf = float(box.conf[0])  # Độ tin cậy (confidence)
        cls = int(box.cls[0])  # Nhãn lớp (class ID)
        class_name = model.names[cls]  # Lấy tên lớp (vd: 'person', 'car',...)

        # Thêm vào danh sách
        image_text_list.append({
            "class": class_name,
            "croped_img": cropped_img_image,
            "bboxs": bbox,
            "confidence": conf
        })

# In kết quả
for obj in image_text_list:
    print(obj)

print(f"Đã phát hiện {len(image_text_list)} vật thể!")
# Out:
# 0: 160x640 1 birth, 52.3ms
# Speed: 0.6ms preprocess, 52.3ms inference, 0.9ms postprocess per image at shape (1, 3, 160, 640)
# {'class': 'birth', 'croped_img': array([[[146, 185, 237],
#         [142, 183, 235],
#         [140, 182, 233],
#         [144, 185, 235],
#         [151, 189, 237],
#         [158, 193, 240],
#         [159, 192, 238],
#         [157, 190, 236],
#         [161, 194, 240],
#         [162, 191, 236],
#         [164, 190, 236]],
#
#        [[139, 177, 227],
#         [142, 180, 230],
#         [145, 183, 234],
#         [135, 173, 222],
#         [121, 157, 204],
#         [111, 145, 191],
#         [117, 150, 196],
#         [132, 166, 211],
#         [155, 189, 234],
#         [166, 195, 240],
#         [164, 191, 236]],
#
#        [[143, 176, 226],
#         [148, 182, 231],
#         [126, 160, 210],
#         [ 78, 112, 160],
#         [ 44,  78, 124],
#         [ 27,  60, 105],
#         [ 39,  72, 117],
#         [ 49,  84, 128],
#         [102, 135, 179],
#         [159, 190, 234],
#         [166, 196, 240]],
#
#        [[154, 187, 233],
#         [130, 162, 208],
#         [ 66,  96, 143],
#         [ 41,  73, 118],
#         [ 63,  96, 140],
#         [ 76, 110, 154],
#         [ 86, 120, 164],
#         [ 47,  82, 125],
#         [ 42,  76, 119],
#         [111, 142, 185],
#         [153, 184, 226]],
#
#        [[132, 162, 206],
#         [119, 147, 192],
#         [ 64,  92, 137],
#         [ 71, 100, 144],
#         [112, 143, 185],
#         [122, 156, 197],
#         [117, 152, 192],
#         [ 96, 132, 173],
#         [ 49,  83, 124],
#         [ 75, 107, 148],
#         [137, 169, 210]],
#
#        [[120, 147, 190],
#         [115, 141, 184],
#         [ 63,  90, 132],
#         [ 73, 103, 144],
#         [119, 152, 191],
#         [136, 172, 210],
#         [135, 171, 209],
#         [111, 147, 187],
#         [ 64,  98, 138],
#         [ 70, 102, 143],
#         [122, 155, 194]],
#
#        [[106, 134, 174],
#         [121, 148, 188],
#         [ 74, 102, 143],
#         [ 60,  91, 131],
#         [ 86, 120, 158],
#         [106, 142, 178],
#         [115, 153, 188],
#         [ 76, 113, 152],
#         [ 61,  96, 136],
#         [ 84, 117, 156],
#         [127, 161, 200]],
#
#        [[108, 138, 177],
#         [127, 158, 198],
#         [ 96, 127, 168],
#         [ 51,  84, 124],
#         [ 26,  62, 100],
#         [ 22,  59,  96],
#         [ 25,  63,  99],
#         [ 23,  60,  98],
#         [ 61,  97, 135],
#         [113, 147, 185],
#         [142, 178, 217]],
#
#        [[101, 133, 172],
#         [107, 140, 181],
#         [ 60,  94, 135],
#         [ 29,  66, 105],
#         [ 54,  92, 131],
#         [ 69, 108, 146],
#         [ 56,  97, 134],
#         [ 36,  76, 113],
#         [ 36,  75, 112],
#         [ 84, 120, 158],
#         [125, 164, 202]],
#
#        [[ 89, 121, 162],
#         [ 62,  98, 140],
#         [ 32,  72, 114],
#         [ 63, 103, 145],
#         [111, 154, 193],
#         [128, 170, 209],
#         [121, 164, 202],
#         [ 97, 140, 176],
#         [ 52,  94, 130],
#         [ 54,  92, 130],
#         [100, 141, 180]],
#
#        [[ 87, 121, 163],
#         [ 48,  86, 130],
#         [ 41,  84, 127],
#         [105, 149, 192],
#         [123, 167, 208],
#         [128, 172, 212],
#         [128, 173, 210],
#         [123, 168, 204],
#         [ 66, 110, 145],
#         [ 38,  79, 116],
#         [ 86, 130, 168]],
#
#        [[ 97, 129, 174],
#         [ 42,  81, 125],
#         [ 41,  84, 127],
#         [113, 158, 201],
#         [121, 165, 208],
#         [125, 168, 210],
#         [124, 168, 208],
#         [132, 176, 214],
#         [ 86, 131, 168],
#         [ 51,  95, 133],
#         [ 82, 128, 166]],
#
#        [[120, 150, 196],
#         [ 69, 107, 151],
#         [ 29,  73, 114],
#         [ 74, 121, 161],
#         [113, 159, 201],
#         [124, 167, 211],
#         [130, 172, 215],
#         [107, 150, 192],
#         [ 54,  98, 139],
#         [ 48,  95, 134],
#         [ 85, 134, 172]],
#
#        [[141, 172, 217],
#         [112, 152, 195],
#         [ 48,  92, 135],
#         [ 23,  72, 114],
#         [ 45,  94, 136],
#         [ 76, 122, 167],
#         [ 75, 118, 164],
#         [ 45,  87, 134],
#         [ 34,  78, 123],
#         [ 74, 121, 165],
#         [102, 152, 193]],
#
#        [[142, 176, 220],
#         [143, 184, 227],
#         [107, 154, 197],
#         [ 53, 103, 145],
#         [ 15,  66, 109],
#         [ 15,  63, 110],
#         [ 20,  66, 115],
#         [ 41,  85, 135],
#         [ 79, 124, 173],
#         [113, 159, 207],
#         [101, 149, 195]]], dtype=uint8), 'bboxs': array([      36.44,      3.9239,      47.429,      18.525], dtype=float32), 'confidence': 0.27732053399086}
# Đã phát hiện 1 vật thể!

# %% [markdown]
# # OCR texts

# %%
preprocesing_image_text_list = []
def preprocessing_image_2blackwhite(img):
    #Resize image 
    #img = cv2.resize(img, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_CUBIC)

    #convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gray = cv2.multiply(gray, 1.5)
    
    #blur remove noise
    blured1 = cv2.medianBlur(gray,3)
    blured2 = cv2.medianBlur(gray,51)
    divided = np.ma.divide(blured1, blured2).data
    normed = np.uint8(255*divided/divided.max())
    
    
    #Threshold image
    th, threshed = cv2.threshold(normed, 0, 255, cv2.THRESH_OTSU + cv2.THRESH_BINARY)
    
    
    return threshed
for img in image_text_list:
    pre_img = preprocessing_image_2blackwhite(img["bbox"])
    preprocesing_image_text_list.append(pre_img)
    display_img(pre_img)
pre_img = preprocessing_image_2blackwhite(image_text_list[0]["croped_img"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 23
#      21     return threshed
#      22 for img in image_text_list:
# ---> 23     pre_img = preprocessing_image_2blackwhite(img["bbox"])
#      24     preprocesing_image_text_list.append(pre_img)
#      25     display_img(pre_img)
#
# KeyError: 'bbox'

# %%
# !pip uninstall -y vietocr pillow
# !pip install --quiet vietocr
# !pip install Pillow
# Out:
# Found existing installation: vietocr 0.3.13
# Uninstalling vietocr-0.3.13:
#   Successfully uninstalled vietocr-0.3.13
# Found existing installation: Pillow 9.5.0
# Uninstalling Pillow-9.5.0:
#   Successfully uninstalled Pillow-9.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.21 requires opencv-contrib-python, which is not installed.
# mediapipe 0.10.21 requires numpy<2, but you have numpy 2.1.1 which is incompatible.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Pillow in /home/anodi108/.local/lib/python3.10/site-packages (10.2.0)

# %%
import matplotlib.pyplot as plt
from PIL import Image

from vietocr.tool.predictor import Predictor
from vietocr.tool.config import Cfg
import numpy as np

YOLO_MODEL_PATH = os.getenv("YOLO_MODEL_PATH", "ocr/best.pt")
CONFIDENCE_THRESHOLD =  0.25
OCR_CONFIG_NAME = "vgg_transformer"
OCR_DEVICE = "cpu"

def load_ocr_model() -> Predictor:
    """Load VietOCR model."""
    config = Cfg.load_config_from_name('vgg_transformer')
    # config['device'] = OCR_DEVICE  # Use GPU if available
    config['cnn']['pretrained']=False
    config['device'] = 'cpu'
    detect =  Predictor(config)
    return detect

ocr_model = load_ocr_model()

# Thực hiện OCR
for text_img in preprocesing_image_text_list:
    if isinstance(text_img, np.ndarray):
        text_img = Image.fromarray(text_img)  # Chuyển numpy -> PIL
    text = ocr_model.predict(text_img)
    print("Kết quả OCR:", text, type(text))
# Out:
# /home/anodi108/anaconda3/envs/checkin_env/lib/python3.10/site-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# 883it [00:20, 43.56it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 22
#      19     detect =  Predictor(config)
#      20     return detect
# ---> 22 ocr_model = load_ocr_model()
#      24 # Thực hiện OCR
#      25 for text_img in preprocesing_image_text_list:
#
# Cell In[16], line 19, in load_ocr_model()
#      17 config['cnn']['pretrained']=False
#      18 config['device'] = 'cpu'
# ---> 19 detect =  Predictor(config)
#      20 return detect
#
# File ~/.local/lib/python3.10/site-packages/vietocr/tool/predictor.py:16, in Predictor.__init__(self, config)
#      13 weights = '/tmp/weights.pth'
#      15 if config['weights'].startswith('http'):
# ---> 16     weights = download_weights(config['weights'])
#      17 else:
#      18     weights = config['weights']
#
# File ~/.local/lib/python3.10/site-packages/vietocr/tool/utils.py:12, in download_weights(uri, cached, md5, quiet)
#      10 def download_weights(uri, cached=None, md5=None, quiet=False):
#      11     if uri.startswith('http'):
# ---> 12         return download(url=uri, quiet=quiet)
#      13     return uri
#
# File ~/.local/lib/python3.10/site-packages/vietocr/tool/utils.py:27, in download(url, quiet)
#      25     r.raise_for_status()
#      26     with open(full_path, 'wb') as f:
# ---> 27         for chunk in tqdm(r.iter_content(chunk_size=8192)):
#      28             # If you have chunk encoded response uncomment if
#      29             # and set chunk_size parameter to None.
#      30             #if chunk:
#      31             f.write(chunk)
#      32 return full_path
#
# File ~/.local/lib/python3.10/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/anaconda3/envs/checkin_env/lib/python3.10/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/anaconda3/envs/checkin_env/lib/python3.10/site-packages/urllib3/response.py:1066, in HTTPResponse.stream(self, amt, decode_content)
#    1064 else:
#    1065     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1066         data = self.read(amt=amt, decode_content=decode_content)
#    1068         if data:
#    1069             yield data
#
# File ~/anaconda3/envs/checkin_env/lib/python3.10/site-packages/urllib3/response.py:955, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     952     if len(self._decoded_buffer) >= amt:
#     953         return self._decoded_buffer.get(amt)
# --> 955 data = self._raw_read(amt)
#     957 flush_decoder = amt is None or (amt != 0 and not data)
#     959 if not data and len(self._decoded_buffer) == 0:
#
# File ~/anaconda3/envs/checkin_env/lib/python3.10/site-packages/urllib3/response.py:879, in HTTPResponse._raw_read(self, amt, read1)
#     876 fp_closed = getattr(self._fp, "closed", False)
#     878 with self._error_catcher():
# --> 879     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     880     if amt is not None and amt != 0 and not data:
#     881         # Platform-specific: Buggy versions of Python.
#     882         # Close the connection when no data is returned
#    (...)
#     887         # not properly close the connection in all cases. There is
#     888         # no harm in redundantly calling close.
#     889         self._fp.close()
#
# File ~/anaconda3/envs/checkin_env/lib/python3.10/site-packages/urllib3/response.py:862, in HTTPResponse._fp_read(self, amt, read1)
#     859     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     860 else:
#     861     # StringIO doesn't like amt=None
# --> 862     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/anaconda3/envs/checkin_env/lib/python3.10/http/client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File ~/anaconda3/envs/checkin_env/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File ~/anaconda3/envs/checkin_env/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/checkin_env/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# !rm /tmp/vgg_transformer.pth

# %%
# !rm /tmp/vgg_transformer.pth

import cv2
from vietocr.tool.predictor import Predictor
from vietocr.tool.config import Cfg
from PIL import Image

# Cấu hình model
OCR_CONFIG_NAME = "vgg_transformer"  # Hoặc 'resnet_transformer', 'vgg_seq2seq'
OCR_DEVICE = 'cpu'  # Hoặc "cuda" nếu dùng GPU
OCR_MODELPATH = '/tmp/vgg_transformer.pth'
# Hàm tải model VietOCR
def load_ocr_model():
    config = Cfg.load_config_from_name(OCR_CONFIG_NAME)
    config['vocab'] = 'aAàÀảẢãÃáÁạẠăĂằẰẳẲẵẴắẮặẶâÂầẦẩẨẫẪấẤậẬbBcCdDđĐeEèÈẻẺẽẼéÉẹẸêÊềỀểỂễỄếẾệỆfFgGhHiIìÌỉỈĩĨíÍịỊjJkKlLmMnNoOòÒỏỎõÕóÓọỌôÔồỒổỔỗỖốỐộỘơƠờỜởỞỡỠớỚợỢpPqQrRsStTuUùÙủỦũŨúÚụỤưƯừỪửỬữỮứỨựỰvVwWxXyYỳỲỷỶỹỸýÝỵỴzZ0123456789!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ '
    config['device'] = OCR_DEVICE
    config['weights'] = "/home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/weights/transformerocr-1.pth"
    config['cnn']['pretrained']=False
    model = Predictor(config)
    return model

# Hàm nhận diện chữ từ ảnh
def recognize_text(image_path):
    ocr_model = load_ocr_model()
    
    img_cv = cv2.imread(image_path)  # Đọc ảnh bằng OpenCV
    img_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)  # Chuyển từ BGR sang RGB
    img = Image.fromarray(img_rgb)
    text = ocr_model.predict(img)  # Thực hiện OCR
    return text

# 🖼 Test với một ảnh
image_path = "/home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/base_cccd.png"  # Đổi thành đường dẫn ảnh của bạn
result = recognize_text(image_path)

ocr_model = load_ocr_model()
img_rgb = cv2.cvtColor(pre_img, cv2.COLOR_BGR2RGB)  # Chuyển từ BGR sang RGB
img = Image.fromarray(img_rgb)
text = ocr_model.predict(img)

print("Kết quả OCR:", text)
# Out:
# Kết quả OCR: ầần ầần ường... Được Hược Hược Hưu Hưu Hưu Hưu Li

# %%
image_path = "/home/anodi108/Desktop/project/Do_An_Tot_Nghiep/DATN_LuThiSen/resource/data/test.jpg"  # Đổi thành đường dẫn ảnh của bạn
result = recognize_text(image_path)
print("Kết quả OCR:", result)
# Out:
# Model weight /tmp/vgg_transformer.pth exsits. Ignore download!
# Kết quả OCR: H

# %%
! wget https://vocr.vn/data/vietocr/data_line.zip
# Out:
# --2025-03-30 08:02:49--  https://vocr.vn/data/vietocr/data_line.zip
# Resolving vocr.vn (vocr.vn)... 128.199.222.116
# Connecting to vocr.vn (vocr.vn)|128.199.222.116|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61212284 (58M) [application/zip]
# Saving to: ‘data_line.zip’
#
# data_line.zip       100%[===================>]  58.38M  1.48MB/s    in 41s
#
# 2025-03-30 08:03:31 (1.41 MB/s) - ‘data_line.zip’ saved [61212284/61212284]
